# %% [markdown]
# <a href="https://colab.research.google.com/github/ZainaHweij/csdiagnostic/blob/main/Test_Trained_One_Model.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Test ACS intracompartmental pressure model using data from sheet

# %% [markdown]
# ## Generate predicted pressure

# %% [markdown]
# Mount Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %% [markdown]
# Test model using CSV data sheet

# %%
import numpy as np
import pandas as pd
import tensorflow as tf

# Load the TensorFlow Lite model
model_path = '/content/drive/My Drive/SEF 2023-2024/TinyML/model_two.tflite'
interpreter = tf.lite.Interpreter(model_path=model_path)
interpreter.allocate_tensors()

# Load data from a CSV file
csv_path = '/content/drive/MyDrive/SEF 2023-2024/TinyML/training_two.csv'
data = pd.read_csv(csv_path)

# Create an empty list to store predicted values
predicted_values = []

for index, row in data.iterrows():
    input_features = row[['fsr_1', 'fsr_2','fsr_3','fsr_4','fsr_5']].values.astype(np.float32)

    # Set input tensor
    input_details = interpreter.get_input_details()
    interpreter.set_tensor(input_details[0]['index'], input_features.reshape(1, -1))

    # Run inference
    interpreter.invoke()

    # Get output tensor
    output_details = interpreter.get_output_details()
    output_data = interpreter.get_tensor(output_details[0]['index']).flatten()  # Flatten the output_data

    # Append the flattened predicted value to the list
    predicted_values.append(output_data)

# Convert the list to a numpy array for easier manipulation
predicted_values = np.array(predicted_values)
print("Predicted values generated.")
# Out:
# Predicted values generated.

# %% [markdown]
# Print all output data if needed

# %%
for index, row in data.iterrows():
    # Process the output data as needed
    print(f"Row {index + 1} - Input Data: {input_features}")
    print(f"Row {index + 1} - Output Data: {output_data}")
    print("=" * 50)

# Print all predicted values in array
print("All Predicted Values:")
print(predicted_values)
# Out:
# Row 1 - Input Data: [80. 77. 97. 72. 94.]
# Row 1 - Output Data: [47.213478]
# ==================================================
# Row 2 - Input Data: [80. 77. 97. 72. 94.]
# Row 2 - Output Data: [47.213478]
# ==================================================
# Row 3 - Input Data: [80. 77. 97. 72. 94.]
# Row 3 - Output Data: [47.213478]
# ==================================================
# Row 4 - Input Data: [80. 77. 97. 72. 94.]
# Row 4 - Output Data: [47.213478]
# ==================================================
# Row 5 - Input Data: [80. 77. 97. 72. 94.]
# Row 5 - Output Data: [47.213478]
# ==================================================
# Row 6 - Input Data: [80. 77. 97. 72. 94.]
# Row 6 - Output Data: [47.213478]
# ==================================================
# Row 7 - Input Data: [80. 77. 97. 72. 94.]
# Row 7 - Output Data: [47.213478]
# ==================================================
# Row 8 - Input Data: [80. 77. 97. 72. 94.]
# Row 8 - Output Data: [47.213478]
# ==================================================
# Row 9 - Input Data: [80. 77. 97. 72. 94.]
# Row 9 - Output Data: [47.213478]
# ==================================================
# Row 10 - Input Data: [80. 77. 97. 72. 94.]
# Row 10 - Output Data: [47.213478]
# ==================================================
# Row 11 - Input Data: [80. 77. 97. 72. 94.]
# Row 11 - Output Data: [47.213478]
# ==================================================
# Row 12 - Input Data: [80. 77. 97. 72. 94.]
# Row 12 - Output Data: [47.213478]
# ==================================================
# Row 13 - Input Data: [80. 77. 97. 72. 94.]
# Row 13 - Output Data: [47.213478]
# ==================================================
# Row 14 - Input Data: [80. 77. 97. 72. 94.]
# Row 14 - Output Data: [47.213478]
# ==================================================
# Row 15 - Input Data: [80. 77. 97. 72. 94.]
# Row 15 - Output Data: [47.213478]
# ==================================================
# Row 16 - Input Data: [80. 77. 97. 72. 94.]
# Row 16 - Output Data: [47.213478]
# ==================================================
# Row 17 - Input Data: [80. 77. 97. 72. 94.]
# Row 17 - Output Data: [47.213478]
# ==================================================
# Row 18 - Input Data: [80. 77. 97. 72. 94.]
# Row 18 - Output Data: [47.213478]
# ==================================================
# Row 19 - Input Data: [80. 77. 97. 72. 94.]
# Row 19 - Output Data: [47.213478]
# ==================================================
# Row 20 - Input Data: [80. 77. 97. 72. 94.]
# Row 20 - Output Data: [47.213478]
# ==================================================
# Row 21 - Input Data: [80. 77. 97. 72. 94.]
# Row 21 - Output Data: [47.213478]
# ==================================================
# Row 22 - Input Data: [80. 77. 97. 72. 94.]
# Row 22 - Output Data: [47.213478]
# ==================================================
# Row 23 - Input Data: [80. 77. 97. 72. 94.]
# Row 23 - Output Data: [47.213478]
# ==================================================
# Row 24 - Input Data: [80. 77. 97. 72. 94.]
# Row 24 - Output Data: [47.213478]
# ==================================================
# Row 25 - Input Data: [80. 77. 97. 72. 94.]
# Row 25 - Output Data: [47.213478]
# ==================================================
# Row 26 - Input Data: [80. 77. 97. 72. 94.]
# Row 26 - Output Data: [47.213478]
# ==================================================
# Row 27 - Input Data: [80. 77. 97. 72. 94.]
# Row 27 - Output Data: [47.213478]
# ==================================================
# Row 28 - Input Data: [80. 77. 97. 72. 94.]
# Row 28 - Output Data: [47.213478]
# ==================================================
# Row 29 - Input Data: [80. 77. 97. 72. 94.]
# Row 29 - Output Data: [47.213478]
# ==================================================
# Row 30 - Input Data: [80. 77. 97. 72. 94.]
# Row 30 - Output Data: [47.213478]
# ==================================================
# Row 31 - Input Data: [80. 77. 97. 72. 94.]
# Row 31 - Output Data: [47.213478]
# ==================================================
# Row 32 - Input Data: [80. 77. 97. 72. 94.]
# Row 32 - Output Data: [47.213478]
# ==================================================
# Row 33 - Input Data: [80. 77. 97. 72. 94.]
# Row 33 - Output Data: [47.213478]
# ==================================================
# Row 34 - Input Data: [80. 77. 97. 72. 94.]
# Row 34 - Output Data: [47.213478]
# ==================================================
# Row 35 - Input Data: [80. 77. 97. 72. 94.]
# Row 35 - Output Data: [47.213478]
# ==================================================
# Row 36 - Input Data: [80. 77. 97. 72. 94.]
# Row 36 - Output Data: [47.213478]
# ==================================================
# Row 37 - Input Data: [80. 77. 97. 72. 94.]
# Row 37 - Output Data: [47.213478]
# ==================================================
# Row 38 - Input Data: [80. 77. 97. 72. 94.]
# Row 38 - Output Data: [47.213478]
# ==================================================
# Row 39 - Input Data: [80. 77. 97. 72. 94.]
# Row 39 - Output Data: [47.213478]
# ==================================================
# Row 40 - Input Data: [80. 77. 97. 72. 94.]
# Row 40 - Output Data: [47.213478]
# ==================================================
# Row 41 - Input Data: [80. 77. 97. 72. 94.]
# Row 41 - Output Data: [47.213478]
# ==================================================
# Row 42 - Input Data: [80. 77. 97. 72. 94.]
# Row 42 - Output Data: [47.213478]
# ==================================================
# Row 43 - Input Data: [80. 77. 97. 72. 94.]
# Row 43 - Output Data: [47.213478]
# ==================================================
# Row 44 - Input Data: [80. 77. 97. 72. 94.]
# Row 44 - Output Data: [47.213478]
# ==================================================
# Row 45 - Input Data: [80. 77. 97. 72. 94.]
# Row 45 - Output Data: [47.213478]
# ==================================================
# Row 46 - Input Data: [80. 77. 97. 72. 94.]
# Row 46 - Output Data: [47.213478]
# ==================================================
# Row 47 - Input Data: [80. 77. 97. 72. 94.]
# Row 47 - Output Data: [47.213478]
# ==================================================
# Row 48 - Input Data: [80. 77. 97. 72. 94.]
# Row 48 - Output Data: [47.213478]
# ==================================================
# Row 49 - Input Data: [80. 77. 97. 72. 94.]
# Row 49 - Output Data: [47.213478]
# ==================================================
# Row 50 - Input Data: [80. 77. 97. 72. 94.]
# Row 50 - Output Data: [47.213478]
# ==================================================
# Row 51 - Input Data: [80. 77. 97. 72. 94.]
# Row 51 - Output Data: [47.213478]
# ==================================================
# Row 52 - Input Data: [80. 77. 97. 72. 94.]
# Row 52 - Output Data: [47.213478]
# ==================================================
# Row 53 - Input Data: [80. 77. 97. 72. 94.]
# Row 53 - Output Data: [47.213478]
# ==================================================
# Row 54 - Input Data: [80. 77. 97. 72. 94.]
# Row 54 - Output Data: [47.213478]
# ==================================================
# Row 55 - Input Data: [80. 77. 97. 72. 94.]
# Row 55 - Output Data: [47.213478]
# ==================================================
# Row 56 - Input Data: [80. 77. 97. 72. 94.]
# Row 56 - Output Data: [47.213478]
# ==================================================
# Row 57 - Input Data: [80. 77. 97. 72. 94.]
# Row 57 - Output Data: [47.213478]
# ==================================================
# Row 58 - Input Data: [80. 77. 97. 72. 94.]
# Row 58 - Output Data: [47.213478]
# ==================================================
# Row 59 - Input Data: [80. 77. 97. 72. 94.]
# Row 59 - Output Data: [47.213478]
# ==================================================
# Row 60 - Input Data: [80. 77. 97. 72. 94.]
# Row 60 - Output Data: [47.213478]
# ==================================================
# Row 61 - Input Data: [80. 77. 97. 72. 94.]
# Row 61 - Output Data: [47.213478]
# ==================================================
# Row 62 - Input Data: [80. 77. 97. 72. 94.]
# Row 62 - Output Data: [47.213478]
# ==================================================
# Row 63 - Input Data: [80. 77. 97. 72. 94.]
# Row 63 - Output Data: [47.213478]
# ==================================================
# Row 64 - Input Data: [80. 77. 97. 72. 94.]
# Row 64 - Output Data: [47.213478]
# ==================================================
# Row 65 - Input Data: [80. 77. 97. 72. 94.]
# Row 65 - Output Data: [47.213478]
# ==================================================
# Row 66 - Input Data: [80. 77. 97. 72. 94.]
# Row 66 - Output Data: [47.213478]
# ==================================================
# Row 67 - Input Data: [80. 77. 97. 72. 94.]
# Row 67 - Output Data: [47.213478]
# ==================================================
# Row 68 - Input Data: [80. 77. 97. 72. 94.]
# Row 68 - Output Data: [47.213478]
# ==================================================
# Row 69 - Input Data: [80. 77. 97. 72. 94.]
# Row 69 - Output Data: [47.213478]
# ==================================================
# Row 70 - Input Data: [80. 77. 97. 72. 94.]
# Row 70 - Output Data: [47.213478]
# ==================================================
# Row 71 - Input Data: [80. 77. 97. 72. 94.]
# Row 71 - Output Data: [47.213478]
# ==================================================
# Row 72 - Input Data: [80. 77. 97. 72. 94.]
# Row 72 - Output Data: [47.213478]
# ==================================================
# Row 73 - Input Data: [80. 77. 97. 72. 94.]
# Row 73 - Output Data: [47.213478]
# ==================================================
# Row 74 - Input Data: [80. 77. 97. 72. 94.]
# Row 74 - Output Data: [47.213478]
# ==================================================
# Row 75 - Input Data: [80. 77. 97. 72. 94.]
# Row 75 - Output Data: [47.213478]
# ==================================================
# Row 76 - Input Data: [80. 77. 97. 72. 94.]
# Row 76 - Output Data: [47.213478]
# ==================================================
# Row 77 - Input Data: [80. 77. 97. 72. 94.]
# Row 77 - Output Data: [47.213478]
# ==================================================
# Row 78 - Input Data: [80. 77. 97. 72. 94.]
# Row 78 - Output Data: [47.213478]
# ==================================================
# Row 79 - Input Data: [80. 77. 97. 72. 94.]
# Row 79 - Output Data: [47.213478]
# ==================================================
# Row 80 - Input Data: [80. 77. 97. 72. 94.]
# Row 80 - Output Data: [47.213478]
# ==================================================
# Row 81 - Input Data: [80. 77. 97. 72. 94.]
# Row 81 - Output Data: [47.213478]
# ==================================================
# Row 82 - Input Data: [80. 77. 97. 72. 94.]
# Row 82 - Output Data: [47.213478]
# ==================================================
# Row 83 - Input Data: [80. 77. 97. 72. 94.]
# Row 83 - Output Data: [47.213478]
# ==================================================
# Row 84 - Input Data: [80. 77. 97. 72. 94.]
# Row 84 - Output Data: [47.213478]
# ==================================================
# Row 85 - Input Data: [80. 77. 97. 72. 94.]
# Row 85 - Output Data: [47.213478]
# ==================================================
# Row 86 - Input Data: [80. 77. 97. 72. 94.]
# Row 86 - Output Data: [47.213478]
# ==================================================
# Row 87 - Input Data: [80. 77. 97. 72. 94.]
# Row 87 - Output Data: [47.213478]
# ==================================================
# Row 88 - Input Data: [80. 77. 97. 72. 94.]
# Row 88 - Output Data: [47.213478]
# ==================================================
# Row 89 - Input Data: [80. 77. 97. 72. 94.]
# Row 89 - Output Data: [47.213478]
# ==================================================
# Row 90 - Input Data: [80. 77. 97. 72. 94.]
# Row 90 - Output Data: [47.213478]
# ==================================================
# Row 91 - Input Data: [80. 77. 97. 72. 94.]
# Row 91 - Output Data: [47.213478]
# ==================================================
# Row 92 - Input Data: [80. 77. 97. 72. 94.]
# Row 92 - Output Data: [47.213478]
# ==================================================
# Row 93 - Input Data: [80. 77. 97. 72. 94.]
# Row 93 - Output Data: [47.213478]
# ==================================================
# Row 94 - Input Data: [80. 77. 97. 72. 94.]
# Row 94 - Output Data: [47.213478]
# ==================================================
# Row 95 - Input Data: [80. 77. 97. 72. 94.]
# Row 95 - Output Data: [47.213478]
# ==================================================
# Row 96 - Input Data: [80. 77. 97. 72. 94.]
# Row 96 - Output Data: [47.213478]
# ==================================================
# Row 97 - Input Data: [80. 77. 97. 72. 94.]
# Row 97 - Output Data: [47.213478]
# ==================================================
# Row 98 - Input Data: [80. 77. 97. 72. 94.]
# Row 98 - Output Data: [47.213478]
# ==================================================
# Row 99 - Input Data: [80. 77. 97. 72. 94.]
# Row 99 - Output Data: [47.213478]
# ==================================================
# Row 100 - Input Data: [80. 77. 97. 72. 94.]
# Row 100 - Output Data: [47.213478]
# ==================================================
# Row 101 - Input Data: [80. 77. 97. 72. 94.]
# Row 101 - Output Data: [47.213478]
# ==================================================
# Row 102 - Input Data: [80. 77. 97. 72. 94.]
# Row 102 - Output Data: [47.213478]
# ==================================================
# Row 103 - Input Data: [80. 77. 97. 72. 94.]
# Row 103 - Output Data: [47.213478]
# ==================================================
# Row 104 - Input Data: [80. 77. 97. 72. 94.]
# Row 104 - Output Data: [47.213478]
# ==================================================
# Row 105 - Input Data: [80. 77. 97. 72. 94.]
# Row 105 - Output Data: [47.213478]
# ==================================================
# Row 106 - Input Data: [80. 77. 97. 72. 94.]
# Row 106 - Output Data: [47.213478]
# ==================================================
# Row 107 - Input Data: [80. 77. 97. 72. 94.]
# Row 107 - Output Data: [47.213478]
# ==================================================
# Row 108 - Input Data: [80. 77. 97. 72. 94.]
# Row 108 - Output Data: [47.213478]
# ==================================================
# Row 109 - Input Data: [80. 77. 97. 72. 94.]
# Row 109 - Output Data: [47.213478]
# ==================================================
# Row 110 - Input Data: [80. 77. 97. 72. 94.]
# Row 110 - Output Data: [47.213478]
# ==================================================
# Row 111 - Input Data: [80. 77. 97. 72. 94.]
# Row 111 - Output Data: [47.213478]
# ==================================================
# Row 112 - Input Data: [80. 77. 97. 72. 94.]
# Row 112 - Output Data: [47.213478]
# ==================================================
# Row 113 - Input Data: [80. 77. 97. 72. 94.]
# Row 113 - Output Data: [47.213478]
# ==================================================
# Row 114 - Input Data: [80. 77. 97. 72. 94.]
# Row 114 - Output Data: [47.213478]
# ==================================================
# Row 115 - Input Data: [80. 77. 97. 72. 94.]
# Row 115 - Output Data: [47.213478]
# ==================================================
# Row 116 - Input Data: [80. 77. 97. 72. 94.]
# Row 116 - Output Data: [47.213478]
# ==================================================
# Row 117 - Input Data: [80. 77. 97. 72. 94.]
# Row 117 - Output Data: [47.213478]
# ==================================================
# Row 118 - Input Data: [80. 77. 97. 72. 94.]
# Row 118 - Output Data: [47.213478]
# ==================================================
# Row 119 - Input Data: [80. 77. 97. 72. 94.]
# Row 119 - Output Data: [47.213478]
# ==================================================
# Row 120 - Input Data: [80. 77. 97. 72. 94.]
# Row 120 - Output Data: [47.213478]
# ==================================================
# Row 121 - Input Data: [80. 77. 97. 72. 94.]
# Row 121 - Output Data: [47.213478]
# ==================================================
# Row 122 - Input Data: [80. 77. 97. 72. 94.]
# Row 122 - Output Data: [47.213478]
# ==================================================
# Row 123 - Input Data: [80. 77. 97. 72. 94.]
# Row 123 - Output Data: [47.213478]
# ==================================================
# Row 124 - Input Data: [80. 77. 97. 72. 94.]
# Row 124 - Output Data: [47.213478]
# ==================================================
# Row 125 - Input Data: [80. 77. 97. 72. 94.]
# Row 125 - Output Data: [47.213478]
# ==================================================
# Row 126 - Input Data: [80. 77. 97. 72. 94.]
# Row 126 - Output Data: [47.213478]
# ==================================================
# Row 127 - Input Data: [80. 77. 97. 72. 94.]
# Row 127 - Output Data: [47.213478]
# ==================================================
# Row 128 - Input Data: [80. 77. 97. 72. 94.]
# Row 128 - Output Data: [47.213478]
# ==================================================
# Row 129 - Input Data: [80. 77. 97. 72. 94.]
# Row 129 - Output Data: [47.213478]
# ==================================================
# Row 130 - Input Data: [80. 77. 97. 72. 94.]
# Row 130 - Output Data: [47.213478]
# ==================================================
# Row 131 - Input Data: [80. 77. 97. 72. 94.]
# Row 131 - Output Data: [47.213478]
# ==================================================
# Row 132 - Input Data: [80. 77. 97. 72. 94.]
# Row 132 - Output Data: [47.213478]
# ==================================================
# Row 133 - Input Data: [80. 77. 97. 72. 94.]
# Row 133 - Output Data: [47.213478]
# ==================================================
# Row 134 - Input Data: [80. 77. 97. 72. 94.]
# Row 134 - Output Data: [47.213478]
# ==================================================
# Row 135 - Input Data: [80. 77. 97. 72. 94.]
# Row 135 - Output Data: [47.213478]
# ==================================================
# Row 136 - Input Data: [80. 77. 97. 72. 94.]
# Row 136 - Output Data: [47.213478]
# ==================================================
# Row 137 - Input Data: [80. 77. 97. 72. 94.]
# Row 137 - Output Data: [47.213478]
# ==================================================
# Row 138 - Input Data: [80. 77. 97. 72. 94.]
# Row 138 - Output Data: [47.213478]
# ==================================================
# Row 139 - Input Data: [80. 77. 97. 72. 94.]
# Row 139 - Output Data: [47.213478]
# ==================================================
# Row 140 - Input Data: [80. 77. 97. 72. 94.]
# Row 140 - Output Data: [47.213478]
# ==================================================
# Row 141 - Input Data: [80. 77. 97. 72. 94.]
# Row 141 - Output Data: [47.213478]
# ==================================================
# Row 142 - Input Data: [80. 77. 97. 72. 94.]
# Row 142 - Output Data: [47.213478]
# ==================================================
# Row 143 - Input Data: [80. 77. 97. 72. 94.]
# Row 143 - Output Data: [47.213478]
# ==================================================
# Row 144 - Input Data: [80. 77. 97. 72. 94.]
# Row 144 - Output Data: [47.213478]
# ==================================================
# Row 145 - Input Data: [80. 77. 97. 72. 94.]
# Row 145 - Output Data: [47.213478]
# ==================================================
# Row 146 - Input Data: [80. 77. 97. 72. 94.]
# Row 146 - Output Data: [47.213478]
# ==================================================
# Row 147 - Input Data: [80. 77. 97. 72. 94.]
# Row 147 - Output Data: [47.213478]
# ==================================================
# Row 148 - Input Data: [80. 77. 97. 72. 94.]
# Row 148 - Output Data: [47.213478]
# ==================================================
# Row 149 - Input Data: [80. 77. 97. 72. 94.]
# Row 149 - Output Data: [47.213478]
# ==================================================
# Row 150 - Input Data: [80. 77. 97. 72. 94.]
# Row 150 - Output Data: [47.213478]
# ==================================================
# Row 151 - Input Data: [80. 77. 97. 72. 94.]
# Row 151 - Output Data: [47.213478]
# ==================================================
# Row 152 - Input Data: [80. 77. 97. 72. 94.]
# Row 152 - Output Data: [47.213478]
# ==================================================
# Row 153 - Input Data: [80. 77. 97. 72. 94.]
# Row 153 - Output Data: [47.213478]
# ==================================================
# Row 154 - Input Data: [80. 77. 97. 72. 94.]
# Row 154 - Output Data: [47.213478]
# ==================================================
# Row 155 - Input Data: [80. 77. 97. 72. 94.]
# Row 155 - Output Data: [47.213478]
# ==================================================
# Row 156 - Input Data: [80. 77. 97. 72. 94.]
# Row 156 - Output Data: [47.213478]
# ==================================================
# Row 157 - Input Data: [80. 77. 97. 72. 94.]
# Row 157 - Output Data: [47.213478]
# ==================================================
# Row 158 - Input Data: [80. 77. 97. 72. 94.]
# Row 158 - Output Data: [47.213478]
# ==================================================
# Row 159 - Input Data: [80. 77. 97. 72. 94.]
# Row 159 - Output Data: [47.213478]
# ==================================================
# Row 160 - Input Data: [80. 77. 97. 72. 94.]
# Row 160 - Output Data: [47.213478]
# ==================================================
# Row 161 - Input Data: [80. 77. 97. 72. 94.]
# Row 161 - Output Data: [47.213478]
# ==================================================
# Row 162 - Input Data: [80. 77. 97. 72. 94.]
# Row 162 - Output Data: [47.213478]
# ==================================================
# Row 163 - Input Data: [80. 77. 97. 72. 94.]
# Row 163 - Output Data: [47.213478]
# ==================================================
# Row 164 - Input Data: [80. 77. 97. 72. 94.]
# Row 164 - Output Data: [47.213478]
# ==================================================
# Row 165 - Input Data: [80. 77. 97. 72. 94.]
# Row 165 - Output Data: [47.213478]
# ==================================================
# Row 166 - Input Data: [80. 77. 97. 72. 94.]
# Row 166 - Output Data: [47.213478]
# ==================================================
# Row 167 - Input Data: [80. 77. 97. 72. 94.]
# Row 167 - Output Data: [47.213478]
# ==================================================
# Row 168 - Input Data: [80. 77. 97. 72. 94.]
# Row 168 - Output Data: [47.213478]
# ==================================================
# Row 169 - Input Data: [80. 77. 97. 72. 94.]
# Row 169 - Output Data: [47.213478]
# ==================================================
# Row 170 - Input Data: [80. 77. 97. 72. 94.]
# Row 170 - Output Data: [47.213478]
# ==================================================
# Row 171 - Input Data: [80. 77. 97. 72. 94.]
# Row 171 - Output Data: [47.213478]
# ==================================================
# Row 172 - Input Data: [80. 77. 97. 72. 94.]
# Row 172 - Output Data: [47.213478]
# ==================================================
# Row 173 - Input Data: [80. 77. 97. 72. 94.]
# Row 173 - Output Data: [47.213478]
# ==================================================
# Row 174 - Input Data: [80. 77. 97. 72. 94.]
# Row 174 - Output Data: [47.213478]
# ==================================================
# Row 175 - Input Data: [80. 77. 97. 72. 94.]
# Row 175 - Output Data: [47.213478]
# ==================================================
# Row 176 - Input Data: [80. 77. 97. 72. 94.]
# Row 176 - Output Data: [47.213478]
# ==================================================
# Row 177 - Input Data: [80. 77. 97. 72. 94.]
# Row 177 - Output Data: [47.213478]
# ==================================================
# Row 178 - Input Data: [80. 77. 97. 72. 94.]
# Row 178 - Output Data: [47.213478]
# ==================================================
# Row 179 - Input Data: [80. 77. 97. 72. 94.]
# Row 179 - Output Data: [47.213478]
# ==================================================
# Row 180 - Input Data: [80. 77. 97. 72. 94.]
# Row 180 - Output Data: [47.213478]
# ==================================================
# Row 181 - Input Data: [80. 77. 97. 72. 94.]
# Row 181 - Output Data: [47.213478]
# ==================================================
# Row 182 - Input Data: [80. 77. 97. 72. 94.]
# Row 182 - Output Data: [47.213478]
# ==================================================
# Row 183 - Input Data: [80. 77. 97. 72. 94.]
# Row 183 - Output Data: [47.213478]
# ==================================================
# Row 184 - Input Data: [80. 77. 97. 72. 94.]
# Row 184 - Output Data: [47.213478]
# ==================================================
# Row 185 - Input Data: [80. 77. 97. 72. 94.]
# Row 185 - Output Data: [47.213478]
# ==================================================
# Row 186 - Input Data: [80. 77. 97. 72. 94.]
# Row 186 - Output Data: [47.213478]
# ==================================================
# Row 187 - Input Data: [80. 77. 97. 72. 94.]
# Row 187 - Output Data: [47.213478]
# ==================================================
# Row 188 - Input Data: [80. 77. 97. 72. 94.]
# Row 188 - Output Data: [47.213478]
# ==================================================
# Row 189 - Input Data: [80. 77. 97. 72. 94.]
# Row 189 - Output Data: [47.213478]
# ==================================================
# Row 190 - Input Data: [80. 77. 97. 72. 94.]
# Row 190 - Output Data: [47.213478]
# ==================================================
# Row 191 - Input Data: [80. 77. 97. 72. 94.]
# Row 191 - Output Data: [47.213478]
# ==================================================
# Row 192 - Input Data: [80. 77. 97. 72. 94.]
# Row 192 - Output Data: [47.213478]
# ==================================================
# Row 193 - Input Data: [80. 77. 97. 72. 94.]
# Row 193 - Output Data: [47.213478]
# ==================================================
# All Predicted Values:
# [[54.337563]
#  [63.395393]
#  [63.606716]
#  [67.07118 ]
#  [67.79737 ]
#  [67.02449 ]
#  [65.75829 ]
#  [63.696644]
#  [63.919823]
#  [65.926796]
#  [63.578697]
#  [69.636635]
#  [69.68785 ]
#  [66.660736]
#  [69.741066]
#  [67.28877 ]
#  [62.694454]
#  [63.424984]
#  [69.28841 ]
#  [71.80059 ]
#  [71.679726]
#  [63.495094]
#  [52.74476 ]
#  [57.78255 ]
#  [55.76362 ]
#  [56.05816 ]
#  [51.66817 ]
#  [57.218952]
#  [53.7002  ]
#  [70.76138 ]
#  [52.366886]
#  [50.150806]
#  [53.295883]
#  [57.22446 ]
#  [72.23354 ]
#  [56.633755]
#  [51.33843 ]
#  [52.615917]
#  [69.7649  ]
#  [59.574444]
#  [58.38807 ]
#  [59.74818 ]
#  [56.16257 ]
#  [58.96613 ]
#  [67.37035 ]
#  [67.13602 ]
#  [74.17306 ]
#  [65.7946  ]
#  [70.93816 ]
#  [68.41394 ]
#  [62.777725]
#  [67.64758 ]
#  [69.28561 ]
#  [64.944786]
#  [65.568436]
#  [68.946   ]
#  [65.375175]
#  [62.536354]
#  [65.24216 ]
#  [68.37682 ]
#  [62.06673 ]
#  [68.78395 ]
#  [63.132202]
#  [67.59121 ]
#  [73.10406 ]
#  [71.27069 ]
#  [66.98829 ]
#  [63.826954]
#  [69.11672 ]
#  [58.445793]
#  [66.98601 ]
#  [60.08947 ]
#  [86.71274 ]
#  [57.348373]
#  [56.98653 ]
#  [60.862507]
#  [65.336586]
#  [68.2781  ]
#  [60.58662 ]
#  [63.894096]
#  [64.292435]
#  [60.572605]
#  [60.912567]
#  [60.847954]
#  [61.52041 ]
#  [65.73955 ]
#  [58.81158 ]
#  [59.170963]
#  [63.09084 ]
#  [53.903194]
#  [64.865456]
#  [73.28745 ]
#  [98.63674 ]
#  [69.65718 ]
#  [65.67248 ]
#  [65.88974 ]
#  [67.38547 ]
#  [73.24119 ]
#  [65.58234 ]
#  [61.131233]
#  [69.70653 ]
#  [68.182175]
#  [68.094666]
#  [64.83365 ]
#  [71.42521 ]
#  [73.0368  ]
#  [68.56859 ]
#  [68.96165 ]
#  [76.4605  ]
#  [61.424713]
#  [73.06812 ]
#  [64.57216 ]
#  [49.938297]
#  [53.125595]
#  [60.634792]
#  [59.369667]
#  [54.50643 ]
#  [58.255875]
#  [56.54109 ]
#  [53.87294 ]
#  [52.372997]
#  [57.11531 ]
#  [64.58073 ]
#  [59.62142 ]
#  [60.19377 ]
#  [56.29661 ]
#  [68.426094]
#  [63.92029 ]
#  [56.48434 ]
#  [61.481197]
#  [66.24819 ]
#  [68.79793 ]
#  [62.950302]
#  [61.451992]
#  [64.92929 ]
#  [67.3661  ]
#  [74.99023 ]
#  [66.98316 ]
#  [65.42182 ]
#  [67.0464  ]
#  [68.25535 ]
#  [56.238483]
#  [61.82039 ]
#  [60.114826]
#  [64.12175 ]
#  [61.797783]
#  [67.12612 ]
#  [66.99113 ]
#  [72.06665 ]
#  [67.12452 ]
#  [61.90375 ]
#  [63.736156]
#  [67.618004]
#  [61.807285]
#  [62.657337]
#  [66.902626]
#  [74.571144]
#  [78.13777 ]
#  [71.24351 ]
#  [65.15766 ]
#  [72.67998 ]
#  [72.31419 ]
#  [70.92658 ]
#  [66.263084]
#  [67.41232 ]
#  [54.91936 ]
#  [70.63671 ]
#  [71.232834]
#  [71.04392 ]
#  [66.79939 ]
#  [71.55447 ]
#  [71.13164 ]
#  [67.747795]
#  [44.23054 ]
#  [53.57557 ]
#  [34.807938]
#  [44.311516]
#  [49.656628]
#  [49.261215]
#  [44.109177]
#  [46.925064]
#  [49.613678]
#  [51.655056]
#  [52.55446 ]
#  [52.890263]
#  [57.44797 ]
#  [51.91701 ]
#  [46.24287 ]
#  [45.28326 ]
#  [46.709576]
#  [50.155   ]
#  [45.4401  ]
#  [47.213478]]

# %% [markdown]
# ## Generate confusion matrix and related performance metrics

# %%
from sklearn.metrics import accuracy_score, confusion_matrix
import sys

threshold = 30

# Convert ground truth to binary labels (1 if disease, 0 if no disease)
ground_truth_labels = (data['ground_truth'] > threshold).astype(int)

# Convert predicted values to binary labels (1 if predicted disease, 0 if predicted no disease)
predicted_labels = (predicted_values > threshold).astype(int)

# Create a file to save the print statements
output_file_path = '/content/drive/MyDrive/SEF 2023-2024/TinyML/Performance/data_fsr_5_210mmHG.txt'
with open(output_file_path, 'w') as file:
    # Redirect stdout to the file
    sys.stdout = file

    # Calculate accuracy using sklearn's accuracy_score
    accuracy = accuracy_score(ground_truth_labels, predicted_labels)

    # Calculate confusion matrix
    conf_matrix = confusion_matrix(ground_truth_labels, predicted_labels)
    print("\nConfusion Matrix:")
    print(conf_matrix)

    # Extract TP, TN, FP, FN from the confusion matrix
    tn, fp, fn, tp = conf_matrix.ravel()

    # Calculate sensitivity (recall), specificity, precision, and F1 score
    sensitivity = tp / (tp + fn) if (tp + fn) != 0 else 0  # Check for division by zero
    specificity = tn / (tn + fp) if (tn + fp) != 0 else 0  # Check for division by zero
    precision = tp / (tp + fp) if (tp + fp) != 0 else 0  # Check for division by zero
    f1_score = 2 * (precision * sensitivity) / (precision + sensitivity) if (precision + sensitivity) != 0 else 0  # Check for division by zero

    print(f"\nAccuracy: {accuracy}")
    print(f"Sensitivity (Recall): {sensitivity}")
    print(f"Specificity: {specificity}")
    print(f"Precision: {precision}")
    print(f"F1 Score: {f1_score}")

# Reset stdout to its default value
sys.stdout = sys.__stdout__

# %% [markdown]
# ## Visualize Data

# %%
pip install matplotlib seaborn

# %% [markdown]
# Visualize Confusion Matrix (heat map)

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Visualize Confusion Matrix
plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', cbar=False,
            xticklabels=['Predicted Negative (0)', 'Predicted Positive (1)'],
            yticklabels=['Actual Negative (0)', 'Actual Positive (1)'])
plt.title('Confusion Matrix')
plt.xlabel('Predicted ACS')
plt.ylabel('True ACS')

save_path = '/content/drive/MyDrive/SEF 2023-2024/TinyML/Performance/CM_fsr_5_210mmHG.png'
plt.savefig(save_path)
plt.show()

# %% [markdown]
# Visualize Metrics (bar chart)

# %%
metrics_names = ['Accuracy', 'Sensitivity (Recall)', 'Specificity', 'Precision', 'F1 Score']
metrics_values = [accuracy, sensitivity, specificity, precision, f1_score]

plt.figure(figsize=(10, 5)) # Higher = better
plt.bar(metrics_names, metrics_values, color=['skyblue', 'lightgreen', 'lightcoral', 'gold', 'orchid']) # Can select other colors
plt.title('Model Performance Metrics')
plt.ylabel('Score')

save_path = '/content/drive/MyDrive/SEF 2023-2024/TinyML/Performance/PM_fsr_5_210mmHG.png'
plt.savefig(save_path)

plt.show()
